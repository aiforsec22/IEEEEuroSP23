# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !CUDA_VISIBLE_DEVICES=0 python "/content/gdrive/MyDrive/Research/malkg/TuckER/single_combination.py" --num_iterations 1000 --dataset 150 --edim 200 --rdim 200 --lr 0.003 --batch_size 32 --input_dropout 0.2 --hidden_dropout1 0.3 --hidden_dropout2 0.5 --label_smoothing 0.2
# Out:
# Streaming output truncated to the last 5000 lines.
# Mean reciprocal rank: 0.1849757555461923
# Test:
# Hits @10: 0.4365482233502538
# Hits @3: 0.19289340101522842
# Hits @1: 0.08629441624365482
# Mean rank: 51.878172588832484
# Mean reciprocal rank: 0.18928135201547
# iteration:  585 / 1000
# 0.049443721771240234
# 0.0517590306699276
# Validation:
# Hits @10: 0.3838383838383838
# Hits @3: 0.1717171717171717
# Hits @1: 0.08080808080808081
# Mean rank: 53.37373737373738
# Mean reciprocal rank: 0.17339597487243322
# iteration:  586 / 1000
# 0.04593825340270996
# 0.052546906284987926
# Validation:
# Hits @10: 0.3838383838383838
# Hits @3: 0.13131313131313133
# Hits @1: 0.08080808080808081
# Mean rank: 53.84848484848485
# Mean reciprocal rank: 0.16677051919076596
# Test:
# Hits @10: 0.43147208121827413
# Hits @3: 0.17258883248730963
# Hits @1: 0.07614213197969544
# Mean rank: 51.45685279187817
# Mean reciprocal rank: 0.18096888988328835
# iteration:  587 / 1000
# 0.04658365249633789
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python "/content/gdrive/MyDrive/Research/malkg/TuckER/single_combination.py" --num_iterations 1000 --dataset 150 --edim 200 --rdim 200 --lr 0.001 --batch_size 32 --input_dropout 0.2 --hidden_dropout1 0.3 --hidden_dropout2 0.5 --label_smoothing 0.2
# Out:
# Streaming output truncated to the last 5000 lines.
# Mean reciprocal rank: 0.19029161646441098
# Test:
# Hits @10: 0.4467005076142132
# Hits @3: 0.2436548223350254
# Hits @1: 0.09137055837563451
# Mean rank: 37.87309644670051
# Mean reciprocal rank: 0.2094695758439708
# iteration:  585 / 1000
# 0.045812129974365234
# 0.052960257045924664
# Validation:
# Hits @10: 0.42424242424242425
# Hits @3: 0.20202020202020202
# Hits @1: 0.08080808080808081
# Mean rank: 42.96969696969697
# Mean reciprocal rank: 0.19023015106743982
# iteration:  586 / 1000
# 0.048162221908569336
# 0.052966888062655926
# Validation:
# Hits @10: 0.40404040404040403
# Hits @3: 0.20202020202020202
# Hits @1: 0.09090909090909091
# Mean rank: 42.656565656565654
# Mean reciprocal rank: 0.1937204490469248
# Test:
# Hits @10: 0.4517766497461929
# Hits @3: 0.22842639593908629
# Hits @1: 0.08121827411167512
# Mean rank: 37.44670050761421
# Mean reciprocal rank: 0.20298903063094664
# iteration:  587 / 1000
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python "/content/gdrive/MyDrive/Research/malkg/TuckER/single_combination.py" --num_iterations 1000 --dataset 150 --edim 50 --rdim 50 --lr 0.001 --batch_size 32 --input_dropout 0.2 --hidden_dropout1 0.3 --hidden_dropout2 0.5 --label_smoothing 0.2
# Out:
# Streaming output truncated to the last 5000 lines.
# Mean reciprocal rank: 0.22719831963456552
# Test:
# Hits @10: 0.583756345177665
# Hits @3: 0.22842639593908629
# Hits @1: 0.10152284263959391
# Mean rank: 21.055837563451778
# Mean reciprocal rank: 0.22708724111653358
# iteration:  585 / 1000
# 0.015858888626098633
# 0.07820473052561283
# Validation:
# Hits @10: 0.48484848484848486
# Hits @3: 0.23232323232323232
# Hits @1: 0.10101010101010101
# Mean rank: 24.141414141414142
# Mean reciprocal rank: 0.22479361627778593
# iteration:  586 / 1000
# 0.018230915069580078
# 0.07737337425351143
# Validation:
# Hits @10: 0.494949494949495
# Hits @3: 0.2222222222222222
# Hits @1: 0.10101010101010101
# Mean rank: 24.232323232323232
# Mean reciprocal rank: 0.22176266703708078
# Test:
# Hits @10: 0.5736040609137056
# Hits @3: 0.2182741116751269
# Hits @1: 0.10152284263959391
# Mean rank: 20.918781725888326
# Mean reciprocal rank: 0.22576121012627373
# iteration:  587 / 1000
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python "/content/gdrive/MyDrive/Research/malkg/TuckER/single_combination.py" --num_iterations 1000 --dataset 150 --edim 50 --rdim 50 --lr 0.001 --batch_size 32 --input_dropout 0.5 --hidden_dropout1 0.5 --hidden_dropout2 0.5 --label_smoothing 0.2
# Out:
# Streaming output truncated to the last 5000 lines.
# iteration:  668 / 1000
# 0.015999317169189453
# 0.08698789775371552
# Validation:
# Hits @30: 0.8383838383838383
# Hits @20: 0.7070707070707071
# Hits @10: 0.5555555555555556
# Hits @3: 0.2222222222222222
# Hits @1: 0.13131313131313133
# Mean rank: 18.747474747474747
# Mean reciprocal rank: 0.24844307317625253
# Test:
# Hits @30: 0.883248730964467
# Hits @20: 0.7918781725888325
# Hits @10: 0.5736040609137056
# Hits @3: 0.27411167512690354
# Hits @1: 0.1116751269035533
# Mean rank: 15.269035532994923
# Mean reciprocal rank: 0.25727519336990473
# iteration:  669 / 1000
# 0.016066551208496094
# 0.08306361734867096
# Validation:
# Hits @30: 0.8484848484848485
# Hits @20: 0.7070707070707071
# Hits @10: 0.5454545454545454
# Hits @3: 0.23232323232323232
# Hits @1: 0.13131313131313133
# Mean rank: 18.696969696969695
# Mean reciprocal rank: 0.2495020141928451
# iteration:  670 / 1000
# 0.014922380447387695
# 0.08387618698179722
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python "/content/gdrive/MyDrive/Research/malkg/TuckER/single_combination.py" --num_iterations 1000 --dataset 7k --edim 50 --rdim 50 --lr 0.001 --batch_size 32 --input_dropout 0.5 --hidden_dropout1 0.5 --hidden_dropout2 0.5 --label_smoothing 0.2
# Out:
# Streaming output truncated to the last 5000 lines.
# Validation:
# Hits @30: 0.8181818181818182
# Hits @20: 0.7070707070707071
# Hits @10: 0.5656565656565656
# Hits @3: 0.36363636363636365
# Hits @1: 0.1919191919191919
# Mean rank: 23.767676767676768
# Mean reciprocal rank: 0.31601992398032663
# Test:
# Hits @30: 0.9238578680203046
# Hits @20: 0.7563451776649747
# Hits @10: 0.5786802030456852
# Hits @3: 0.3147208121827411
# Hits @1: 0.1319796954314721
# Mean rank: 16.573604060913706
# Mean reciprocal rank: 0.2730130752025686
# iteration:  253 / 1000
# 0.09040045738220215
# 0.03027688482633004
# Validation:
# Hits @30: 0.8181818181818182
# Hits @20: 0.696969696969697
# Hits @10: 0.5555555555555556
# Hits @3: 0.3434343434343434
# Hits @1: 0.18181818181818182
# Mean rank: 20.80808080808081
# Mean reciprocal rank: 0.3057605532564423
# iteration:  254 / 1000
# 0.08926200866699219
# 0.030309969989153054
# Validation:
# Hits @30: 0.8282828282828283
# Hits @20: 0.696969696969697
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python "/content/gdrive/MyDrive/Research/malkg/TuckER/single_combination.py" --num_iterations 1000 --dataset 7k_atk_loc --edim 50 --rdim 50 --lr 0.001 --batch_size 32 --input_dropout 0.5 --hidden_dropout1 0.5 --hidden_dropout2 0.5 --label_smoothing 0.2
# Out:
# Streaming output truncated to the last 5000 lines.
# iteration:  668 / 1000
# 0.16774582862854004
# 0.016139730568165363
# Validation:
# Hits @30: 0.8080808080808081
# Hits @20: 0.7070707070707071
# Hits @10: 0.5555555555555556
# Hits @3: 0.3434343434343434
# Hits @1: 0.18181818181818182
# Mean rank: 29.595959595959595
# Mean reciprocal rank: 0.3060279374603477
# Test:
# Hits @30: 0.9238578680203046
# Hits @20: 0.7715736040609137
# Hits @10: 0.583756345177665
# Hits @3: 0.3197969543147208
# Hits @1: 0.14213197969543148
# Mean rank: 21.487309644670052
# Mean reciprocal rank: 0.2784352364678521
# iteration:  669 / 1000
# 0.1604161262512207
# 0.01627010540307864
# Validation:
# Hits @30: 0.8080808080808081
# Hits @20: 0.7272727272727273
# Hits @10: 0.5353535353535354
# Hits @3: 0.3333333333333333
# Hits @1: 0.1717171717171717
# Mean rank: 29.646464646464647
# Mean reciprocal rank: 0.29836578174821954
# iteration:  670 / 1000
# 0.1649484634399414
# 0.016245391078131353
# Validation:
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python "/content/gdrive/MyDrive/Research/malkg/TuckER/single_combination.py" --num_iterations 1000 --dataset 7k_atk_loc_ioc --edim 50 --rdim 50 --lr 0.001 --batch_size 32 --input_dropout 0.5 --hidden_dropout1 0.5 --hidden_dropout2 0.5 --label_smoothing 0.2
# Out:
# Streaming output truncated to the last 5000 lines.
# iteration:  668 / 1000
# 0.8977148532867432
# 0.002418664905100899
# Validation:
# Hits @30: 0.8181818181818182
# Hits @20: 0.7070707070707071
# Hits @10: 0.5555555555555556
# Hits @3: 0.3838383838383838
# Hits @1: 0.1919191919191919
# Mean rank: 33.78787878787879
# Mean reciprocal rank: 0.3180799318809327
# Test:
# Hits @30: 0.9086294416243654
# Hits @20: 0.7614213197969543
# Hits @10: 0.5634517766497462
# Hits @3: 0.30456852791878175
# Hits @1: 0.14213197969543148
# Mean rank: 13.274111675126903
# Mean reciprocal rank: 0.2766464198124186
# iteration:  669 / 1000
# 0.9148731231689453
# 0.002432953857857248
# Validation:
# Hits @30: 0.8181818181818182
# Hits @20: 0.7070707070707071
# Hits @10: 0.5454545454545454
# Hits @3: 0.40404040404040403
# Hits @1: 0.18181818181818182
# Mean rank: 39.343434343434346
# Mean reciprocal rank: 0.3180481805169441
# iteration:  670 / 1000
# 0.9185779094696045
# 0.0024103876658836784
# Validation:
# ...
